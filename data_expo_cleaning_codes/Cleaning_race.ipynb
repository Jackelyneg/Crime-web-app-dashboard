# %%
import pandas as pd
import numpy as np
import requests
import json
import time
import datetime
from config import tmdb_key
from pprint import pprint
from sqlalchemy import create_engine
from config import password, username
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-900f4a7dadd3> in <module>
#       5 import time
#       6 import datetime
# ----> 7 from config import tmdb_key
#       8 from pprint import pprint
#       9 from sqlalchemy import create_engine
#
# ModuleNotFoundError: No module named 'config'

# %%
race_table_2014 = pd.read_csv("raw_data (1)_2014.csv")
race_table_2015 = pd.read_csv("raw_data (2)_2015.csv")
race_table_2016 = pd.read_csv("raw_data (3)_2016.csv")
race_table_2017 = pd.read_csv("raw_data (4)_2017.csv")
race_table_2018 = pd.read_csv("raw_data (5)_2018.csv")

# %%
race_table_2014["Year"] = "2014"
race_table_2015["Year"] = "2015"
race_table_2016["Year"] = "2016"
race_table_2017["Year"] = "2017"
race_table_2018["Year"] = "2018"

# %%
df_2014 = pd.DataFrame(race_table_2014)
df_2015 = pd.DataFrame(race_table_2015)
df_2016 = pd.DataFrame(race_table_2016)
df_2017 = pd.DataFrame(race_table_2017)
df_2018 = pd.DataFrame(race_table_2018)

# %%
df_2018.head()
# Out:
#       Location  White  Black  Hispanic  Asian American Indian/Alaska Native  \
# 0  Connecticut  0.663  0.099     0.166  0.047                          <.01
# 1     Delaware  0.621  0.213     0.095  0.042                          <.01
# 2      Florida  0.533  0.151     0.263  0.027                          <.01
# 3      Georgia  0.525  0.309     0.097  0.041                          <.01
# 4        Maine  0.934  0.013     0.015  0.013                          <.01
#
#   Native Hawaiian/Other Pacific Islander  Year
# 0                                    NaN  2018
# 1                                    NaN  2018
# 2                                   <.01  2018
# 3                                   <.01  2018
# 4                                    NaN  2018

# %%
all_race = pd.concat([df_2014, df_2015,df_2016,df_2017,df_2018])

# %%
all_race
# Out:
#           Location  White  Black  Hispanic  Asian  \
# 0      Connecticut  0.688  0.095     0.151  0.042
# 1         Delaware  0.639  0.210     0.089  0.039
# 2          Florida  0.557  0.153     0.243  0.026
# 3          Georgia  0.545  0.306     0.092  0.037
# 4            Maine  0.938  0.012     0.012  0.010
# ..             ...    ...    ...       ...    ...
# 12    Rhode Island  0.715  0.056     0.160  0.034
# 13  South Carolina  0.638  0.263     0.058  0.016
# 14         Vermont  0.929  0.011     0.018  0.019
# 15        Virginia  0.615  0.186     0.095  0.066
# 16   West Virginia  0.925  0.036     0.013  0.008
#
#    American Indian/Alaska Native Native Hawaiian/Other Pacific Islander  Year
# 0                           <.01                                    NaN  2014
# 1                           <.01                                    NaN  2014
# 2                           <.01                                   <.01  2014
# ...

# %%
all_race = all_race.rename(columns = {"Location":"state"})

# %%
all_race.head(20)
# Out:
#              state  White  Black  Hispanic  Asian  \
# 0      Connecticut  0.688  0.095     0.151  0.042
# 1         Delaware  0.639  0.210     0.089  0.039
# 2          Florida  0.557  0.153     0.243  0.026
# 3          Georgia  0.545  0.306     0.092  0.037
# 4            Maine  0.938  0.012     0.012  0.010
# 5         Maryland  0.525  0.291     0.094  0.062
# 6    Massachusetts  0.740  0.065     0.108  0.060
# 7    New Hampshire  0.913  0.011     0.032  0.025
# 8       New Jersey  0.568  0.125     0.194  0.092
# 9         New York  0.564  0.143     0.187  0.081
# 10  North Carolina  0.641  0.213     0.090  0.024
# 11    Pennsylvania  0.781  0.104     0.065  0.031
# 12    Rhode Island  0.741  0.054     0.142  0.032
# 13  South Carolina  0.641  0.271     0.053  0.014
# 14         Vermont  0.934  0.010     0.015  0.020
# 15        Virginia  0.631  0.187     0.088  0.062
# 16   West Virginia  0.929  0.035     0.012  0.010
# 17             NaN    NaN    NaN       NaN    NaN
# ...

# %%
del all_race["American Indian/Alaska Native"]

# %%
del all_race["Native Hawaiian/Other Pacific Islander"]

# %%
all_race
# Out:
#              state  White  Black  Hispanic  Asian  Year
# 0      Connecticut  0.688  0.095     0.151  0.042  2014
# 1         Delaware  0.639  0.210     0.089  0.039  2014
# 2          Florida  0.557  0.153     0.243  0.026  2014
# 3          Georgia  0.545  0.306     0.092  0.037  2014
# 4            Maine  0.938  0.012     0.012  0.010  2014
# ..             ...    ...    ...       ...    ...   ...
# 12    Rhode Island  0.715  0.056     0.160  0.034  2018
# 13  South Carolina  0.638  0.263     0.058  0.016  2018
# 14         Vermont  0.929  0.011     0.018  0.019  2018
# 15        Virginia  0.615  0.186     0.095  0.066  2018
# 16   West Virginia  0.925  0.036     0.013  0.008  2018
#
# [91 rows x 6 columns]

# %%
all_race.dropna()
# Out:
#              state  White  Black  Hispanic  Asian  Year
# 0      Connecticut  0.688  0.095     0.151  0.042  2014
# 1         Delaware  0.639  0.210     0.089  0.039  2014
# 2          Florida  0.557  0.153     0.243  0.026  2014
# 3          Georgia  0.545  0.306     0.092  0.037  2014
# 4            Maine  0.938  0.012     0.012  0.010  2014
# ..             ...    ...    ...       ...    ...   ...
# 12    Rhode Island  0.715  0.056     0.160  0.034  2018
# 13  South Carolina  0.638  0.263     0.058  0.016  2018
# 14         Vermont  0.929  0.011     0.018  0.019  2018
# 15        Virginia  0.615  0.186     0.095  0.066  2018
# 16   West Virginia  0.925  0.036     0.013  0.008  2018
#
# [85 rows x 6 columns]

# %%
all_race.to_csv("all_race_2.csv")

# %%
all_race.reset_index(drop=True, inplace = True)

# %%
all_race
# Out:
#              state  White  Black  Hispanic  Asian  Year
# 0      Connecticut  0.688  0.095     0.151  0.042  2014
# 1         Delaware  0.639  0.210     0.089  0.039  2014
# 2          Florida  0.557  0.153     0.243  0.026  2014
# 3          Georgia  0.545  0.306     0.092  0.037  2014
# 4            Maine  0.938  0.012     0.012  0.010  2014
# ..             ...    ...    ...       ...    ...   ...
# 86    Rhode Island  0.715  0.056     0.160  0.034  2018
# 87  South Carolina  0.638  0.263     0.058  0.016  2018
# 88         Vermont  0.929  0.011     0.018  0.019  2018
# 89        Virginia  0.615  0.186     0.095  0.066  2018
# 90   West Virginia  0.925  0.036     0.013  0.008  2018
#
# [91 rows x 6 columns]

# %%
all_race.head(30)
# Out:
#              state  White  Black  Hispanic  Asian  Year
# 0      Connecticut  0.688  0.095     0.151  0.042  2014
# 1         Delaware  0.639  0.210     0.089  0.039  2014
# 2          Florida  0.557  0.153     0.243  0.026  2014
# 3          Georgia  0.545  0.306     0.092  0.037  2014
# 4            Maine  0.938  0.012     0.012  0.010  2014
# 5         Maryland  0.525  0.291     0.094  0.062  2014
# 6    Massachusetts  0.740  0.065     0.108  0.060  2014
# 7    New Hampshire  0.913  0.011     0.032  0.025  2014
# 8       New Jersey  0.568  0.125     0.194  0.092  2014
# 9         New York  0.564  0.143     0.187  0.081  2014
# 10  North Carolina  0.641  0.213     0.090  0.024  2014
# 11    Pennsylvania  0.781  0.104     0.065  0.031  2014
# 12    Rhode Island  0.741  0.054     0.142  0.032  2014
# 13  South Carolina  0.641  0.271     0.053  0.014  2014
# 14         Vermont  0.934  0.010     0.015  0.020  2014
# 15        Virginia  0.631  0.187     0.088  0.062  2014
# ...

# %%
all_race.dropna(inplace=True)

# %%
all_race
# Out:
#              state  White  Black  Hispanic  Asian  Year
# 0      Connecticut  0.688  0.095     0.151  0.042  2014
# 1         Delaware  0.639  0.210     0.089  0.039  2014
# 2          Florida  0.557  0.153     0.243  0.026  2014
# 3          Georgia  0.545  0.306     0.092  0.037  2014
# 4            Maine  0.938  0.012     0.012  0.010  2014
# ..             ...    ...    ...       ...    ...   ...
# 86    Rhode Island  0.715  0.056     0.160  0.034  2018
# 87  South Carolina  0.638  0.263     0.058  0.016  2018
# 88         Vermont  0.929  0.011     0.018  0.019  2018
# 89        Virginia  0.615  0.186     0.095  0.066  2018
# 90   West Virginia  0.925  0.036     0.013  0.008  2018
#
# [85 rows x 6 columns]

# %%
state_df=pd.read_csv("state_1.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-a6c75ed8bc20> in <module>
# ----> 1 state_df=pd.read_csv("state_1.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %%
# Out:
#                                                                <<<<<<< HEAD
# NaN                                              state_abbr           state
# 0                                                NY                New York
# 1                                                NJ              New Jersey
# 2                                                ME                   Maine
# 3                                                NH           New Hampshire
# 4                                                MA           Massachusetts
# 5                                                WV           West Virginia
# 6                                                CT             Connecticut
# 7                                                RI            Rhode Island
# 8                                                VA                Virginia
# 9                                                NC          North Carolina
# ...

# %%
all_race=pd.merge(state_df,all_race, on="state",how="inner")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-dab32dbdfbcb> in <module>
# ----> 1 all_race=pd.merge(state_df,all_race, on="state",how="inner")
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     666             self.right_join_keys,
#     667             self.join_names,
# --> 668         ) = self._get_merge_keys()
#     669
# ...

# %%
all_race

# %%
all_race = all_race.drop(columns=list(all_race)[3])

# %%
all_race

# %%
all_race.to_csv("final_race.csv")

# %%
mvs_connection_string = f"{username}:{password}@localhost:5432/crime_bs"
engine = create_engine(f'postgresql://{mvs_connection_string}')
