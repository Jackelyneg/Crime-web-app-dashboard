# %%
import pandas as pd
import numpy as np

# %%
education_df = pd.read_excel('Education Data.xlsx')

# %%
education_df.head()
# Out:
#                                           Table S-15  \
# 0  Individuals with High School or Higher Level D...
# 1                                                NaN
# 2                                              State
# 3                                      United States
# 4                                            Alabama
#
#                               Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                                    NaN         NaN         NaN         NaN
# 1  High school graduates 25–44 years old         NaN         NaN         NaN
# 2                                   2005      2006.0      2007.0      2008.0
# 3                               72084295  73373035.0  73232215.0  73006065.0
# 4                                1035195   1041195.0   1036145.0   1046900.0
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
#education_df = education_df.drop(columns=list(education_df)[1:33])

education_df = education_df.drop(columns=list(education_df)[1:10])
education_df = education_df.drop(columns=list(education_df)[6:17])
education_df = education_df.drop(columns=list(education_df)[11:22])
education_df = education_df.drop(columns=list(education_df)[1:11])
education_df = education_df.drop(columns=list(education_df)[-1])
education_df
# Out:
#                                            Table S-15  Unnamed: 42  \
# 0   Individuals with High School or Higher Level D...          NaN
# 1                                                 NaN          NaN
# 2                                               State  2014.000000
# 3                                       United States    88.691336
# 4                                             Alabama    86.945746
# ..                                                ...          ...
# 58  NOTES: The national total for degree holders f...          NaN
# 59  SOURCE: U.S. Census Bureau, special tabulation...          NaN
# 60  Recommended Citation: National Science Board. ...          NaN
# 61                       Last updated: March 24, 2021          NaN
# 62                 Science and Engineering Indicators          NaN
#
#     Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46
# 0           NaN          NaN          NaN          NaN
# ...

# %%
education_df = education_df.drop(labels=0, axis=0)
education_df = education_df.drop(labels=1, axis=0)

education_df
# Out:
#                                            Table S-15  Unnamed: 42  \
# 2                                               State  2014.000000
# 3                                       United States    88.691336
# 4                                             Alabama    86.945746
# 5                                              Alaska    93.687931
# 6                                             Arizona    85.304470
# ..                                                ...          ...
# 58  NOTES: The national total for degree holders f...          NaN
# 59  SOURCE: U.S. Census Bureau, special tabulation...          NaN
# 60  Recommended Citation: National Science Board. ...          NaN
# 61                       Last updated: March 24, 2021          NaN
# 62                 Science and Engineering Indicators          NaN
#
#     Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46
# 2   2015.000000  2016.000000  2017.000000  2018.000000
# ...

# %%
education_df.dropna(inplace=True)

# %%
#education_df  #Total # individuals 25 to 44 HS Degree or Higher - Total # of individuals 25 to 44 - % with HS Degree or Higher

# %%
education_df.reset_index(drop=True)
# Out:
#               Table S-15  Unnamed: 42  Unnamed: 43  Unnamed: 44  Unnamed: 45  \
# 0                  State  2014.000000  2015.000000  2016.000000  2017.000000
# 1          United States    88.691336    88.982537    88.926928    89.779826
# 2                Alabama    86.945746    87.104255    86.949719    87.762041
# 3                 Alaska    93.687931    93.858065    94.531970    93.028049
# 4                Arizona    85.304470    85.233680    85.265774    86.691977
# 5               Arkansas    88.265014    88.204804    86.980467    88.401588
# 6             California    84.492004    84.830633    84.986565    87.048034
# 7               Colorado    90.116506    91.226437    89.971620    91.196313
# 8            Connecticut    91.765014    92.915094    92.432118    92.407133
# 9               Delaware    89.574455    88.465024    89.098426    91.945212
# 10  District of Columbia    92.115319    92.375181    91.273675    93.187203
# ...

# %%
new_header = education_df.iloc[0] #grab the first row for the header
new_header
# Out:
# Table S-15     State
# Unnamed: 42     2014
# Unnamed: 43     2015
# Unnamed: 44     2016
# Unnamed: 45     2017
# Unnamed: 46     2018
# Name: 2, dtype: object

# %%
education_df = education_df[1:] #take the data less the header row

# %%
education_df.columns = new_header #set the header row as the df header

# %%
education_df.columns.name = None

# %%
education_df.reset_index(inplace=True)

# %%
education_df= education_df.drop(columns=['index'])

# %%
drop_list = [0,1,2,3,4,5,6,9,12,13,14,15,16,17,18,19,23,24,25,26,27,28,29,32,35,36,37,38,42,43,44,45,48,50,51,52]
#drop_list

# %%
for i in drop_list:
    education_df.drop([i], inplace=True)

# %%
#education_df

# %%
#education_df.round(2)

# %%
years = [2014, 2015, 2016, 2017, 2018]
states = ['CT', 'DE', 'FL', 'GA', 'MA', 'MD', 'ME', 'NC', 'NH', 'NJ', 'NY', 'PA', 'RI', 'SC', 'VA', 'VT', 'WV']
education = []

# %%
education_2014 = education_df.iloc[:,1]
education_2015 = education_df.iloc[:,2]
education_2016 = education_df.iloc[:,3]
education_2017 = education_df.iloc[:,4]
education_2018 = education_df.iloc[:,5]

# %%
for i in education_2014:
    education.append(i)

# %%
for i in education_2015:
    education.append(i)

# %%
for i in education_2016:
    education.append(i)

# %%
for i in education_2017:
    education.append(i)

# %%
for i in education_2018:
    education.append(i)

# %%
#education

# %%
data=[]
data_list=[]

for i in years:
    for j in states:
        data.append(i)
        data.append(j)
        
data
# Out:
# [2014,
#  'CT',
#  2014,
#  'DE',
#  2014,
#  'FL',
#  2014,
#  'GA',
#  2014,
#  'MA',
#  2014,
#  'MD',
#  2014,
#  'ME',
#  2014,
#  'NC',
#  2014,
#  'NH',
#  2014,
#  'NJ',
#  2014,
#  'NY',
#  2014,
#  'PA',
#  2014,
#  'RI',
#  2014,
#  'SC',
#  2014,
#  'VA',
#  2014,
#  'VT',
#  2014,
#  'WV',
#  2015,
#  'CT',
#  2015,
#  'DE',
#  2015,
#  'FL',
#  2015,
#  'GA',
#  2015,
#  'MA',
#  2015,
#  'MD',
#  2015,
#  'ME',
#  2015,
#  'NC',
#  2015,
#  'NH',
#  2015,
#  'NJ',
#  2015,
#  'NY',
#  2015,
#  'PA',
#  2015,
#  'RI',
#  2015,
#  'SC',
#  2015,
#  'VA',
#  2015,
#  'VT',
#  2015,
#  'WV',
#  2016,
#  'CT',
#  2016,
#  'DE',
#  2016,
#  'FL',
#  2016,
#  'GA',
#  2016,
#  'MA',
#  2016,
#  'MD',
#  2016,
#  'ME',
#  2016,
#  'NC',
#  2016,
#  'NH',
#  2016,
#  'NJ',
#  2016,
#  'NY',
#  2016,
#  'PA',
#  2016,
#  'RI',
#  2016,
#  'SC',
#  2016,
#  'VA',
#  2016,
#  'VT',
#  2016,
#  'WV',
#  2017,
#  'CT',
#  2017,
#  'DE',
#  2017,
#  'FL',
#  2017,
#  'GA',
#  2017,
# ...

# %%
x = 2
data_list = [data[i:i+x] for i in range(0, len(data), x)]

# %%
#data_list

# %%
df = pd.DataFrame(data_list, columns=['Year', 'State'])
df
# Out:
#     Year State
# 0   2014    CT
# 1   2014    DE
# 2   2014    FL
# 3   2014    GA
# 4   2014    MA
# ..   ...   ...
# 80  2018    RI
# 81  2018    SC
# 82  2018    VA
# 83  2018    VT
# 84  2018    WV
#
# [85 rows x 2 columns]

# %%
education_df=pd.DataFrame(education, columns=['Education'])
education_df
# Out:
#     Education
# 0   91.765014
# 1   89.574455
# 2   88.655541
# 3   87.205725
# 4   94.652116
# ..        ...
# 80  93.053324
# 81  89.634153
# 82  95.986823
# 83  92.278102
# 84  90.997072
#
# [85 rows x 1 columns]

# %%
final_education_df= pd.concat([df, education_df], axis=1)
final_education_df
# Out:
#     Year State  Education
# 0   2014    CT  91.765014
# 1   2014    DE  89.574455
# 2   2014    FL  88.655541
# 3   2014    GA  87.205725
# 4   2014    MA  94.652116
# ..   ...   ...        ...
# 80  2018    RI  93.053324
# 81  2018    SC  89.634153
# 82  2018    VA  95.986823
# 83  2018    VT  92.278102
# 84  2018    WV  90.997072
#
# [85 rows x 3 columns]

# %%
final_education_df.round(2)
# Out:
#     Year State  Education
# 0   2014    CT      91.77
# 1   2014    DE      89.57
# 2   2014    FL      88.66
# 3   2014    GA      87.21
# 4   2014    MA      94.65
# ..   ...   ...        ...
# 80  2018    RI      93.05
# 81  2018    SC      89.63
# 82  2018    VA      95.99
# 83  2018    VT      92.28
# 84  2018    WV      91.00
#
# [85 rows x 3 columns]

# %%
final_education_df.to_csv("educationData.csv")
